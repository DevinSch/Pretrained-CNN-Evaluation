# %%
import torch
import torchvision.models as models

from Helper_funcs import *

# %%
model = models.inception_v3(weights='DEFAULT')
model_aug = models.inception_v3(weights='DEFAULT')
model_name = 'Inception_v3'
input_size = 299

# %%
# Load dataset, replace classifier, and display the model architecture
train_loader, val_loader, test_loader = load_dataset(input_size, False)
replace_classifier(model, model_name)
display_model(model, input_size)
# Out:
# Input size = (3, 299, 299)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 149, 149]             864
#        BatchNorm2d-2         [-1, 32, 149, 149]              64
#        BasicConv2d-3         [-1, 32, 149, 149]               0
#             Conv2d-4         [-1, 32, 147, 147]           9,216
#        BatchNorm2d-5         [-1, 32, 147, 147]              64
#        BasicConv2d-6         [-1, 32, 147, 147]               0
#             Conv2d-7         [-1, 64, 147, 147]          18,432
#        BatchNorm2d-8         [-1, 64, 147, 147]             128
#        BasicConv2d-9         [-1, 64, 147, 147]               0
#         MaxPool2d-10           [-1, 64, 73, 73]               0
#            Conv2d-11           [-1, 80, 73, 73]           5,120
#       BatchNorm2d-12           [-1, 80, 73, 73]             160
# ...

# %%
# train the model
train(model, train_loader, val_loader, ('./models/best_' + model_name + '.pth'))

# %%
# Load the best preforming model, test classification time and overall accuracy
model.load_state_dict(torch.load(('./models/best_' + model_name + '.pth'), weights_only=True))
evaluate_time(model)
evaluate_accuracy(model, test_loader)

# %%
# Print a confusion matrix of predicted vs actual class labels
create_confusion_matrix(model, test_loader)

# %%
# Train another model with the augmented dataset
train_loader_aug, val_loader_aug, test_loader_aug = load_dataset(input_size, True)
replace_classifier(model_aug, model_name)
train(model_aug, train_loader_aug, val_loader_aug, ('./models/best_' + model_name + '_augmented.pth'))
# Out:
# Using: [cuda] - [NVIDIA GeForce RTX 3080]
# Saving the model with validation accuracy: 0.9013
# Epoch [1/30], Training Loss: 0.3322 - Validation Loss: 0.3623 - Validation Accuracy: 0.9013
# Epoch [2/30], Training Loss: 0.1155 - Validation Loss: 1.2989 - Validation Accuracy: 0.6065
# Saving the model with validation accuracy: 0.9739
# Epoch [3/30], Training Loss: 0.0879 - Validation Loss: 0.1209 - Validation Accuracy: 0.9739
# Saving the model with validation accuracy: 0.9938
# Epoch [4/30], Training Loss: 0.0603 - Validation Loss: 0.0190 - Validation Accuracy: 0.9938
# Epoch [5/30], Training Loss: 0.0688 - Validation Loss: 1.6077 - Validation Accuracy: 0.4902
# Epoch [6/30], Training Loss: 0.0657 - Validation Loss: 0.7214 - Validation Accuracy: 0.7864
# Epoch [7/30], Training Loss: 0.0471 - Validation Loss: 1.4687 - Validation Accuracy: 0.5030
# Epoch [8/30], Training Loss: 0.0428 - Validation Loss: 0.0428 - Validation Accuracy: 0.9884
# ...

# %%
# Test the accuracy of the model with augmented data
model_aug.load_state_dict(torch.load(('./models/best_' + model_name + '_augmented.pth'), weights_only=True))
evaluate_accuracy(model_aug, test_loader_aug)
# Out:
# Overall test accuracy: 99.38%

# %%
# Print a confusion matrix of predicted vs actual class labels
create_confusion_matrix(model_aug, test_loader_aug)
